# %% [markdown]
# <a href="https://colab.research.google.com/github/Javierxd1383/MineriaDeDatos/blob/main/Mineria_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria De Datos

# %% [markdown]
# ## Primer Parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos
# 1. El Proceso KDD (Knowledge Discovery in Databases)
# La minería de datos no es un paso aislado, sino parte de un proceso más grande llamado Descubrimiento de Conocimiento en Bases de Datos. Los pasos principales son:
#
#
#
# *   Limpieza de datos: Eliminar ruido o datos inconsistentes.
# *   Limpieza de datos: Eliminar ruido o datos inconsistentes.
#
# * Integración: Combinar múltiples fuentes de datos.
#
# * Selección y Transformación: Elegir los datos relevantes y convertirlos a formatos aptos para el análisis.
#
# * Minería de datos: Aplicar algoritmos para extraer patrones.
#
# * Evaluación y Presentación: Interpretar los resultados y visualizarlos.

# %% [markdown]
# #### Ciencia de Datos

# %% [markdown]
# hol
